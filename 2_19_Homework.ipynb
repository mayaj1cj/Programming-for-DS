# %% [markdown]
# <a href="https://colab.research.google.com/github/mayaj1cj/Programming-for-DS/blob/main/2_19_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hi there!

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# plt.imshow("numpy_nature")

from skimage import io

photo = io.imread('numpy_nature')

print(photo)

photo[0,1] = (21, 0, 0)

# plt.imshow(photo[0,1])

# red_photo

# photo.shape = (200, 300, 3)
# Out:
# [[[ 21  44  24]
#   [ 21  44  24]
#   [ 23  44  25]
#   ...
#   [172 195 153]
#   [158 180 131]
#   [155 175 122]]
#
#  [[ 21  44  24]
#   [ 21  44  24]
#   [ 23  44  25]
#   ...
#   [170 193 149]
#   [156 176 125]
#   [149 170 114]]
#
#  [[ 21  44  24]
#   [ 21  44  24]
#   [ 23  44  25]
#   ...
#   [168 190 144]
#   [150 168 116]
#   [141 160 104]]
#
#  ...
#
#  [[ 74  62  46]
#   [ 67  58  41]
#   [ 68  56  40]
#   ...
#   [ 49  57  18]
#   [ 49  53  20]
#   [ 47  50  19]]
#
#  [[ 56  47  32]
#   [ 58  51  35]
#   [ 68  59  44]
#   ...
#   [ 45  53  14]
#   [ 50  54  21]
#   [ 50  54  21]]
#
#  [[ 76  69  53]
#   [ 65  58  42]
#   [ 57  50  34]
#   ...
#   [ 47  55  16]
#   [ 52  56  21]
#   [ 53  57  24]]]

# %%
import numpy as np

print(photo.shape)

blue_channel = photo[:,:,0]

blue_channel[:] = 0

plt.imshow(photo)
plt.axis("off")
plt.show("numpy_nature")
# Out:
# (200, 300, 3)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# print(photo.shape)

# !pip install opencv-python

photo = np.random.randint(0, 255, size=(200, 300, 3), dtype=np.uint8)

red_channel = photo[:,:,0]

red_channel[:] = 0

cv2.imwrite('red_photo.jpg', red_channel)

img = cv2.imread('red_photo.jpg')

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# ...
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 441, in run
#     conflicts = self._determine_conflicts(to_install)
# ...

# %%
# print(photo)

# photo[:,:,2] = 0


import cv2

# img_color = cv2.imread('numpy_nature',1)
# img_grayscale = cv2.imread('numpy_nature',0)
# img_unchanged = cv2.imread('numpy_nature',-1)

plt.imshow(img_color)
plt.axis("off")
blue_photo = plt.show(photo)

#plt.imshow(photo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-21f5fd0bbec1> in <cell line: 14>()
#      12 plt.imshow(img_color)
#      13 plt.axis("off")
# ---> 14 blue_photo = plt.show(photo)
#      15
#      16 #plt.imshow(photo)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     444     """
#     445     _warn_if_gui_out_of_main_thread()
# --> 446     return _get_backend_mod().show(*args, **kwargs)
#     447
#     448
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      96         # only call close('all') if any to close
#      97         # close triggers gc.collect, which can be slow
# ---> 98         if close and Gcf.get_all_fig_managers():
#      99             matplotlib.pyplot.close('all')
#     100
#
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)
